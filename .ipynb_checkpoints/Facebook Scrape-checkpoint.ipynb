# %%
#Celdas de impotacion
from time import sleep
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
from selenium.common.exceptions import NoSuchElementException
from ipywidgets import widgets
from datetime import datetime
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

#Base de datos
db = client.FB_Scrap

#Obtenemos Coleciones
DB_post = db.FB_Posts

# %%
def set_values(sender):
    global email_user
    global pass_user
    email_user=u.value
    pass_user=p.value

# %%
u=widgets.Text(description='Usuario:')
p=widgets.Password(description='Contraseña:')
b=widgets.Button(description="Ingresar!")

email_user=''
pass_user=''

display(u)
display(p)
display(b)



u.on_submit(set_values)
p.on_submit(set_values)
b.on_click(set_values)
# Out:
# Text(value='', description='Usuario:')
# Password(description='Contraseña:')
# Button(description='Ingresar!', style=ButtonStyle())

# %%
#Celdas de seteo de variables

#Ruta del driver de Chrome o Firefox
diver_path="C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe"

#Order by para las publicaciones
order_post='?sorting_setting=CHRONOLOGICAL'
#order_post='?sorting_setting=TOP_POSTS'
#order_post='?sorting_setting=RECENT_ACTIVITY'

#Seteo el url del grupo
#url_group='https://www.facebook.com/groups/160048240785769/'
#url_group='https://www.facebook.com/groups/1030505903629786/'
url_group='https://www.facebook.com/groups/alquileresruta9/'


#Configuracion para deshabilitar "show notificacion"
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)

# %%
driver = webdriver.Chrome(diver_path,chrome_options=chrome_options)

driver.get('https://www.facebook.com/login.php?login_attempt=1&lwv=110')
print("Facebook Abierto...")
email = driver.find_element_by_xpath("//input[@id='email' or @name='email']")
email.send_keys(email_user)
print("Email ingresado...")
password = driver.find_element_by_xpath("//input[@id='pass']")
password.send_keys(pass_user)
print("Password ingresado...")
button = driver.find_element_by_xpath("//button[@id='loginbutton']")
button.click()
print("Facebook abierto")

print('Yendo al grupo')

driver.get(url_group+order_post)


# game=driver.find_element_by_tag_name('body')
# game.click()

for itera in range(1000):
     #game.send_keys(Keys.SPACE)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(0.5)

# commentaires = driver.find_elements_by_xpath("//div [@data-testid='UFI2Comment/body']")
#post_id = driver.find_elements_by_xpath("//div [@data-testid='story-subtitle']")
#post_dates = driver.find_elements_by_xpath("//div [@class='_5ptz']")
post_id = driver.find_elements_by_class_name("_5pcq")

print('Cantidad de Post :', str(len(post_id)))

post_id_list=[]

for p in post_id:
    #print(com.text)
    post_id_list.append(p.get_attribute('href'))
# Out:
# C:\Users\Usuario\Miniconda3\envs\DataScience\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: use options instead of chrome_options
#   """Entry point for launching an IPython kernel.
# Facebook Abierto...
# Email ingresado...
# Password ingresado...
# Facebook abierto
# Yendo al grupo
# Cantidad de Post : 842

# %%
#Limpio los ids para poder usarlos en los urls
# post_id_list = [w.replace('feed_subtitle_', '') for w in post_id_list]
# post_id_list = [w.replace(':6:0', '') for w in post_id_list]
post_id_list

# %%
len(post_id_list)
post_id_list=['https://www.facebook.com/groups/fierroscordobeses/permalink/1657204474403464/?sale_post_id=1657204474403464']

# %%
# driver = webdriver.Chrome(diver_path)
post_id=''
date_post=''
user_link=''
user_name=''
msg_post=''
post_comment=''
user_name_comment=''
user_link_comment=''
comment_id=''
date_comment=''

for pid in post_id_list:
    
    data_post={}
    comments_post=[]

    #driver.get(url_group+'permalink/'+pid+'/')
    driver.get(pid)
    
    #Expandir respuestas
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    click_answer=driver.find_elements_by_xpath("//div [@class='_4swz _1i3s _293g']")
    print(len(click_answer))
    if len(click_answer)>0:
        for c in click_answer:
            try:
                c.click()
            except Exception as e:
                print('Error: ',e)
                pass
            sleep(0.5)
    
    post_dates = driver.find_elements_by_class_name("_5ptz")
    #post_user=driver.find_elements_by_class_name("_5pb8 e_r160ugzvu _8o _8s lfloat _ohe") 
    post_user = driver.find_elements_by_xpath("//a[@class='_5pb8 e_r160ugzvu _8o _8s lfloat _ohe']")
    #print(post_user)
    post_msg = driver.find_elements_by_xpath("//div [@ data-testid='post_message']")
    post_ids = driver.find_elements_by_xpath("//input [@ name='ft_ent_identifier']")
    
   
    
    if len(post_dates)>0:
        timestamP=int(post_dates[0].get_attribute('data-utime'))
        tP=datetime.fromtimestamp(timestamP)
        date_post=datetime.strptime(tP.strftime('%d/%m/%y %H:%M:%S'),'%d/%m/%y %H:%M:%S')
    else:
        date_post=''
        
    if len(post_user)>0:
        user_link=post_user[0].get_attribute('href')
        user_name=post_user[0].get_attribute('title')
    else:
        user_link=''
        user_name=''
        
    if len(post_msg)>0:
        msg_post=post_msg[0].text
    else:
        msg_post=''
        
    if len(post_ids)>0:
        post_id=post_ids[0].get_attribute('value')
    else:
        post_id=''
            
    
    ##leemos comentarios
    #comments = driver.find_elements_by_class_name("_72vr")
    comments = driver.find_elements_by_xpath("//div [@ data-testid='UFI2Comment/root_depth_0']")
    #print(comments)
    
    if len(comments)>0:
        for idx,com in enumerate(comments):
            try:
                #Primero obtengo el id limpio del comentario
                comment_id=com.get_attribute('data-ft')
                comment_id=comment_id.replace('{"tn":"R","ct":"','')
                comment_id=comment_id.replace('="}','')
                
                com1=com.find_element_by_class_name("_72vr")
                com2=com.find_element_by_class_name("_6qw7")
                
                post_comment=com1.find_element_by_xpath("./span[@dir='ltr']").text
                user_name_comment=com1.find_element_by_xpath("./a[@class='_6qw4']").text
                user_link_comment=com1.find_element_by_xpath("./a[@class='_6qw4']").get_attribute('href')
                
                timestamp=int(com2.find_element_by_xpath("./abbr[@class='livetimestamp']").get_attribute('data-utime'))
                t=datetime.fromtimestamp(timestamp)
                date_comment=datetime.strptime(t.strftime('%d/%m/%y %H:%M:%S'),'%d/%m/%y %H:%M:%S')
                
                #comments_post.append([comment_id,user_name_comment,user_link_comment,post_comment,date_comment])
                comments_post.append({
                    'comment_id':comment_id,
                    'user_name_comment':user_name_comment,
                    'user_link_comment':user_link_comment,
                    'post_comment':post_comment,
                    'date_comment':date_comment,
                    'type' : 'reply'
                })
                
            except Exception as e2:
                print('Error:', e2)
                pass
        
    #data_post.append([pid,post_id,date_post,user_link,user_name,msg_post,comments_post])
    data_post={
        'post_id':post_id,
        'post_link':pid,
        'date_post':date_post,
        'user_link':user_link,
        'user_name':user_name,
        'msg_post':msg_post,
        'type' : 'post',
        'comments_post':comments_post
    }
    
    id_=DB_post.insert_one(data_post).inserted_id
    print(id_)
    
    sleep(0.5)
# Out:
# 0
# 5e58435bf76b1a73b0c4a843
# 0
# 5e58435df76b1a73b0c4a844
# 0
# 5e58435ff76b1a73b0c4a845
# 0
# 5e584361f76b1a73b0c4a846
# 0
# 5e584364f76b1a73b0c4a847
# 0
# 5e584365f76b1a73b0c4a848
# 0
# 5e58436bf76b1a73b0c4a849
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584374f76b1a73b0c4a84a
# 0
# 5e584376f76b1a73b0c4a84b
# 0
# 5e584378f76b1a73b0c4a84c
# 0
# 5e58437af76b1a73b0c4a84d
# 0
# 5e58437cf76b1a73b0c4a84e
# 0
# 5e58437ef76b1a73b0c4a84f
# 0
# 5e584380f76b1a73b0c4a850
# 0
# 5e584382f76b1a73b0c4a851
# 0
# 5e584384f76b1a73b0c4a852
# 0
# 5e584386f76b1a73b0c4a853
# 0
# 5e584387f76b1a73b0c4a854
# 0
# 5e584389f76b1a73b0c4a855
# 0
# 5e58438bf76b1a73b0c4a856
# 0
# 5e58438df76b1a73b0c4a857
# 0
# 5e58438ff76b1a73b0c4a858
# 0
# 5e584391f76b1a73b0c4a859
# 0
# 5e584393f76b1a73b0c4a85a
# 0
# 5e584394f76b1a73b0c4a85b
# 0
# 5e584396f76b1a73b0c4a85c
# 0
# 5e584398f76b1a73b0c4a85d
# 0
# 5e58439af76b1a73b0c4a85e
# 0
# 5e58439cf76b1a73b0c4a85f
# 0
# 5e5843a1f76b1a73b0c4a860
# 0
# 5e5843a3f76b1a73b0c4a861
# 0
# 5e5843a5f76b1a73b0c4a862
# 0
# 5e5843a7f76b1a73b0c4a863
# 0
# 5e5843a9f76b1a73b0c4a864
# 0
# 5e5843aaf76b1a73b0c4a865
# 0
# 5e5843acf76b1a73b0c4a866
# 0
# 5e5843aef76b1a73b0c4a867
# 0
# 5e5843b0f76b1a73b0c4a868
# 0
# 5e5843b2f76b1a73b0c4a869
# 0
# 5e5843b4f76b1a73b0c4a86a
# 0
# 5e5843b6f76b1a73b0c4a86b
# 0
# 5e5843b8f76b1a73b0c4a86c
# 0
# 5e5843baf76b1a73b0c4a86d
# 0
# 5e5843bdf76b1a73b0c4a86e
# 0
# 5e5843bef76b1a73b0c4a86f
# 0
# 5e5843c0f76b1a73b0c4a870
# 0
# 5e5843c2f76b1a73b0c4a871
# 0
# 5e5843c5f76b1a73b0c4a872
# 0
# 5e5843c7f76b1a73b0c4a873
# 0
# 5e5843c8f76b1a73b0c4a874
# 0
# 5e5843cef76b1a73b0c4a875
# 0
# 5e5843d6f76b1a73b0c4a876
# 0
# 5e5843d8f76b1a73b0c4a877
# 0
# 5e584470f76b1a73b0c4a8b5
# 0
# 5e584472f76b1a73b0c4a8b6
# 0
# 5e584474f76b1a73b0c4a8b7
# 0
# 5e584476f76b1a73b0c4a8b8
# 0
# 5e584479f76b1a73b0c4a8b9
# 0
# 5e584481f76b1a73b0c4a8ba
# 0
# 5e584484f76b1a73b0c4a8bb
# 0
# 5e584486f76b1a73b0c4a8bc
# 0
# 5e58448bf76b1a73b0c4a8bd
# 0
# 5e58448df76b1a73b0c4a8be
# 0
# 5e58448ff76b1a73b0c4a8bf
# 0
# 5e584494f76b1a73b0c4a8c0
# 0
# 5e584498f76b1a73b0c4a8c1
# 0
# 5e58449cf76b1a73b0c4a8c2
# 0
# 5e58449ef76b1a73b0c4a8c3
# 0
# 5e5844a1f76b1a73b0c4a8c4
# 0
# 5e5844a2f76b1a73b0c4a8c5
# 0
# 5e5844a4f76b1a73b0c4a8c6
# 0
# 5e5844a6f76b1a73b0c4a8c7
# 0
# 5e5844a8f76b1a73b0c4a8c8
# 0
# 5e5844aaf76b1a73b0c4a8c9
# 0
# 5e5844acf76b1a73b0c4a8ca
# 0
# 5e5844aef76b1a73b0c4a8cb
# 0
# 5e5844b0f76b1a73b0c4a8cc
# 0
# 5e5844b2f76b1a73b0c4a8cd
# 3
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e5844bbf76b1a73b0c4a8ce
# 0
# 5e5844bdf76b1a73b0c4a8cf
# 0
# 5e5844bff76b1a73b0c4a8d0
# 0
# 5e5844c1f76b1a73b0c4a8d1
# 0
# 5e5844c3f76b1a73b0c4a8d2
# 0
# 5e5844c5f76b1a73b0c4a8d3
# 0
# 5e5844c7f76b1a73b0c4a8d4
# 0
# 5e5844c9f76b1a73b0c4a8d5
# 0
# 5e5844cbf76b1a73b0c4a8d6
# 0
# 5e5844cdf76b1a73b0c4a8d7
# 0
# 5e5844cff76b1a73b0c4a8d8
# 0
# 5e5844d1f76b1a73b0c4a8d9
# 0
# 5e5844d6f76b1a73b0c4a8da
# 0
# 5e5844d9f76b1a73b0c4a8db
# 0
# 5e5844dbf76b1a73b0c4a8dc
# 0
# 5e5844ddf76b1a73b0c4a8dd
# 0
# 5e5844def76b1a73b0c4a8de
# 0
# 5e5844e0f76b1a73b0c4a8df
# 0
# 5e5844e3f76b1a73b0c4a8e0
# 0
# 5e5844e4f76b1a73b0c4a8e1
# 0
# 5e5844e7f76b1a73b0c4a8e2
# 0
# 5e5844e9f76b1a73b0c4a8e3
# 0
# 5e5844eaf76b1a73b0c4a8e4
# 0
# 5e5844ecf76b1a73b0c4a8e5
# 0
# 5e5844eef76b1a73b0c4a8e6
# 0
# 5e5844f2f76b1a73b0c4a8e7
# 0
# 5e5844f7f76b1a73b0c4a8e8
# 0
# 5e5844fef76b1a73b0c4a8e9
# 0
# 5e584500f76b1a73b0c4a8ea
# 0
# 5e584502f76b1a73b0c4a8eb
# 0
# 5e584505f76b1a73b0c4a8ec
# 0
# 5e584507f76b1a73b0c4a8ed
# 0
# 5e58450bf76b1a73b0c4a8ee
# 0
# 5e58450cf76b1a73b0c4a8ef
# 0
# 5e58450ff76b1a73b0c4a8f0
# 1
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e584514f76b1a73b0c4a8f1
# 0
# 5e584516f76b1a73b0c4a8f2
# 0
# 5e584518f76b1a73b0c4a8f3
# 0
# 5e58451af76b1a73b0c4a8f4
# 0
# 5e58451cf76b1a73b0c4a8f5
# 0
# 5e58451ef76b1a73b0c4a8f6
# 0
# 5e584520f76b1a73b0c4a8f7
# 0
# 5e584522f76b1a73b0c4a8f8
# 0
# 5e584526f76b1a73b0c4a8f9
# 0
# 5e584528f76b1a73b0c4a8fa
# 0
# 5e58452af76b1a73b0c4a8fb
# 0
# 5e58452bf76b1a73b0c4a8fc
# 0
# 5e58452df76b1a73b0c4a8fd
# 0
# 5e58452ff76b1a73b0c4a8fe
# 0
# 5e584531f76b1a73b0c4a8ff
# 0
# 5e584533f76b1a73b0c4a900
# 0
# 5e584535f76b1a73b0c4a901
# 0
# 5e58453cf76b1a73b0c4a902
# 0
# 5e58453ff76b1a73b0c4a903
# 0
# 5e584541f76b1a73b0c4a904
# 0
# 5e584543f76b1a73b0c4a905
# 0
# 5e584545f76b1a73b0c4a906
# 1
# Error:  Message: element click intercepted: Element is not clickable at point (471, 990)
#   (Session info: chrome=80.0.3987.122)
#
# 5e584549f76b1a73b0c4a907
# 0
# 5e58454bf76b1a73b0c4a908
# 0
# 5e58454df76b1a73b0c4a909
# 0
# 5e58454ff76b1a73b0c4a90a
# 0
# 5e584551f76b1a73b0c4a90b
# 0
# 5e584553f76b1a73b0c4a90c
# 0
# 5e584555f76b1a73b0c4a90d
# 0
# 5e58455af76b1a73b0c4a90e
# 0
# 5e584562f76b1a73b0c4a90f
# 0
# 5e584566f76b1a73b0c4a910
# 0
# 5e584568f76b1a73b0c4a911
# 1
# 5e58456bf76b1a73b0c4a912
# 0
# 5e58456ff76b1a73b0c4a913
# 0
# 5e584571f76b1a73b0c4a914
# 0
# 5e584573f76b1a73b0c4a915
# 0
# 5e584575f76b1a73b0c4a916
# 0
# 5e584577f76b1a73b0c4a917
# 0
# 5e584579f76b1a73b0c4a918
# 0
# 5e58457bf76b1a73b0c4a919
# 0
# 5e58457df76b1a73b0c4a91a
# 0
# 5e58457ff76b1a73b0c4a91b
# 0
# 5e584583f76b1a73b0c4a91c
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584746f76b1a73b0c4a9cc
# 0
# 5e58474ef76b1a73b0c4a9cd
# 0
# 5e584753f76b1a73b0c4a9ce
# 0
# 5e584757f76b1a73b0c4a9cf
# 0
# 5e584759f76b1a73b0c4a9d0
# 2
# Error:  Message: element click intercepted: Element is not clickable at point (471, -24)
#   (Session info: chrome=80.0.3987.122)
#
# 5e584761f76b1a73b0c4a9d1
# 0
# 5e584765f76b1a73b0c4a9d2
# 0
# 5e584767f76b1a73b0c4a9d3
# 0
# 5e58476cf76b1a73b0c4a9d4
# 0
# 5e58476ef76b1a73b0c4a9d5
# 0
# 5e584772f76b1a73b0c4a9d6
# 0
# 5e584775f76b1a73b0c4a9d7
# 0
# 5e584777f76b1a73b0c4a9d8
# 0
# 5e58477df76b1a73b0c4a9d9
# 0
# 5e58477ff76b1a73b0c4a9da
# 0
# 5e584781f76b1a73b0c4a9db
# 0
# 5e584785f76b1a73b0c4a9dc
# 0
# 5e584787f76b1a73b0c4a9dd
# 0
# 5e58478af76b1a73b0c4a9de
# 0
# 5e58478ef76b1a73b0c4a9df
# 0
# 5e584790f76b1a73b0c4a9e0
# 0
# 5e584793f76b1a73b0c4a9e1
# 0
# 5e584795f76b1a73b0c4a9e2
# 3
# Error:  Message: element click intercepted: Element is not clickable at point (471, -3397)
#   (Session info: chrome=80.0.3987.122)
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5847a1f76b1a73b0c4a9e3
# 0
# 5e5847a4f76b1a73b0c4a9e4
# 0
# 5e5847a6f76b1a73b0c4a9e5
# 0
# 5e5847a8f76b1a73b0c4a9e6
# 0
# 5e5847adf76b1a73b0c4a9e7
# 0
# 5e5847b4f76b1a73b0c4a9e8
# 0
# 5e5847b7f76b1a73b0c4a9e9
# 0
# 5e5847bcf76b1a73b0c4a9ea
# 0
# 5e5847bff76b1a73b0c4a9eb
# 0
# 5e5847c3f76b1a73b0c4a9ec
# 0
# 5e5847c5f76b1a73b0c4a9ed
# 0
# 5e5847cbf76b1a73b0c4a9ee
# 0
# 5e5847cdf76b1a73b0c4a9ef
# 0
# 5e5847cff76b1a73b0c4a9f0
# 1
# 5e5847d4f76b1a73b0c4a9f1
# 0
# 5e5847d7f76b1a73b0c4a9f2
# 0
# 5e5847d9f76b1a73b0c4a9f3
# 0
# 5e5847daf76b1a73b0c4a9f4
# 0
# 5e5847ddf76b1a73b0c4a9f5
# 0
# 5e5847e0f76b1a73b0c4a9f6
# 0
# 5e5847e3f76b1a73b0c4a9f7
# 1
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e5847e8f76b1a73b0c4a9f8
# 0
# 5e5847eaf76b1a73b0c4a9f9
# 0
# 5e5847ecf76b1a73b0c4a9fa
# 0
# 5e5847eef76b1a73b0c4a9fb
# 0
# 5e5847f0f76b1a73b0c4a9fc
# 0
# 5e5847f6f76b1a73b0c4a9fd
# 0
# 5e5847f8f76b1a73b0c4a9fe
# 0
# 5e5847fbf76b1a73b0c4a9ff
# 0
# 5e5847fdf76b1a73b0c4aa00
# 0
# 5e5847fff76b1a73b0c4aa01
# 0
# 5e584801f76b1a73b0c4aa02
# 0
# 5e584803f76b1a73b0c4aa03
# 3
# Error:  Message: element click intercepted: Element is not clickable at point (471, 854)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1125)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1564)
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584810f76b1a73b0c4aa04
# 0
# 5e584815f76b1a73b0c4aa05
# 0
# 5e58481af76b1a73b0c4aa06
# 0
# 5e58481ef76b1a73b0c4aa07
# 0
# 5e584820f76b1a73b0c4aa08
# 0
# 5e584823f76b1a73b0c4aa09
# 0
# 5e584825f76b1a73b0c4aa0a
# 0
# 5e584828f76b1a73b0c4aa0b
# 0
# 5e58482af76b1a73b0c4aa0c
# 0
# 5e58482cf76b1a73b0c4aa0d
# 0
# 5e58482ef76b1a73b0c4aa0e
# 0
# 5e584830f76b1a73b0c4aa0f
# 0
# 5e584836f76b1a73b0c4aa10
# 0
# 5e584838f76b1a73b0c4aa11
# 4
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e584847f76b1a73b0c4aa12
# 0
# 5e584849f76b1a73b0c4aa13
# 0
# 5e58484bf76b1a73b0c4aa14
# 0
# 5e58484df76b1a73b0c4aa15
# 0
# 5e58484ff76b1a73b0c4aa16
# 7
# Error:  Message: element click intercepted: Element is not clickable at point (471, -4174)
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e58485ef76b1a73b0c4aa17
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584868f76b1a73b0c4aa18
# 0
# 5e58486af76b1a73b0c4aa19
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584872f76b1a73b0c4aa1a
# 0
# 5e584876f76b1a73b0c4aa1b
# 0
# 5e58487cf76b1a73b0c4aa1c
# 0
# 5e58487df76b1a73b0c4aa1d
# 0
# 5e58487ff76b1a73b0c4aa1e
# 0
# 5e584881f76b1a73b0c4aa1f
# 0
# 5e584883f76b1a73b0c4aa20
# 0
# 5e584885f76b1a73b0c4aa21
# 0
# 5e584887f76b1a73b0c4aa22
# 0
# 5e584888f76b1a73b0c4aa23
# 0
# 5e58488bf76b1a73b0c4aa24
# 0
# 5e58488df76b1a73b0c4aa25
# 0
# 5e58488ff76b1a73b0c4aa26
# 1
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584896f76b1a73b0c4aa27
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e58489df76b1a73b0c4aa28
# 0
# 5e58489ff76b1a73b0c4aa29
# 0
# 5e5848a2f76b1a73b0c4aa2a
# 0
# 5e5848a4f76b1a73b0c4aa2b
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5848abf76b1a73b0c4aa2c
# 0
# 5e5848adf76b1a73b0c4aa2d
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5848b2f76b1a73b0c4aa2e
# 0
# 5e5848b4f76b1a73b0c4aa2f
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./a[@class='_6qw4']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5848b7f76b1a73b0c4aa30
# 0
# 5e5848b9f76b1a73b0c4aa31
# 0
# 5e5848bcf76b1a73b0c4aa32
# 0
# 5e5848c0f76b1a73b0c4aa33
# 0
# 5e5848c2f76b1a73b0c4aa34
# 0
# 5e5848c4f76b1a73b0c4aa35
# 0
# 5e5848c7f76b1a73b0c4aa36
# 0
# 5e5848c8f76b1a73b0c4aa37
# 9
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5848e2f76b1a73b0c4aa38
# 0
# 5e5848e4f76b1a73b0c4aa39
# 0
# 5e5848e6f76b1a73b0c4aa3a
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5848edf76b1a73b0c4aa3b
# 0
# 5e5848eff76b1a73b0c4aa3c
# 0
# 5e5848f1f76b1a73b0c4aa3d
# 0
# 5e5848f3f76b1a73b0c4aa3e
# 0
# 5e5848f6f76b1a73b0c4aa3f
# 0
# 5e5848f8f76b1a73b0c4aa40
# 0
# 5e5848fcf76b1a73b0c4aa41
# 0
# 5e5848fef76b1a73b0c4aa42
# 8
# Error:  Message: element click intercepted: Element is not clickable at point (471, -403)
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e58490bf76b1a73b0c4aa43
# 0
# 5e58490df76b1a73b0c4aa44
# 0
# 5e58490ff76b1a73b0c4aa45
# 0
# 5e584911f76b1a73b0c4aa46
# 0
# 5e584916f76b1a73b0c4aa47
# 0
# 5e584919f76b1a73b0c4aa48
# 0
# 5e58491bf76b1a73b0c4aa49
# 0
# 5e58491df76b1a73b0c4aa4a
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./a[@class='_6qw4']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./a[@class='_6qw4']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584922f76b1a73b0c4aa4b
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e58492bf76b1a73b0c4aa4c
# 0
# 5e58492ef76b1a73b0c4aa4d
# 0
# 5e58492ff76b1a73b0c4aa4e
# 0
# 5e584932f76b1a73b0c4aa4f
# 0
# 5e584935f76b1a73b0c4aa50
# 0
# 5e584938f76b1a73b0c4aa51
# 0
# 5e58493bf76b1a73b0c4aa52
# 0
# 5e584942f76b1a73b0c4aa53
# 0
# 5e584945f76b1a73b0c4aa54
# 0
# 5e584948f76b1a73b0c4aa55
# 0
# 5e58494cf76b1a73b0c4aa56
# 0
# 5e58494ef76b1a73b0c4aa57
# 0
# 5e584952f76b1a73b0c4aa58
# 0
# 5e584954f76b1a73b0c4aa59
# 0
# 5e584957f76b1a73b0c4aa5a
# 0
# 5e584959f76b1a73b0c4aa5b
# 0
# 5e58495cf76b1a73b0c4aa5c
# 2
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e584962f76b1a73b0c4aa5d
# 25
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584982f76b1a73b0c4aa5e
# 0
# 5e584984f76b1a73b0c4aa5f
# 0
# 5e584988f76b1a73b0c4aa60
# 0
# 5e58498bf76b1a73b0c4aa61
# 0
# 5e58498df76b1a73b0c4aa62
# 0
# 5e584990f76b1a73b0c4aa63
# 0
# 5e584994f76b1a73b0c4aa64
# 0
# 5e584996f76b1a73b0c4aa65
# 0
# 5e58499af76b1a73b0c4aa66
# 0
# 5e58499ff76b1a73b0c4aa67
# 0
# 5e5849a6f76b1a73b0c4aa68
# 0
# 5e5849a9f76b1a73b0c4aa69
# 0
# 5e5849abf76b1a73b0c4aa6a
# 0
# 5e5849aef76b1a73b0c4aa6b
# 0
# 5e5849b0f76b1a73b0c4aa6c
# 0
# 5e5849b2f76b1a73b0c4aa6d
# 0
# 5e5849b6f76b1a73b0c4aa6e
# 0
# 5e5849bbf76b1a73b0c4aa6f
# 0
# 5e5849bff76b1a73b0c4aa70
# 0
# 5e5849c2f76b1a73b0c4aa71
# 0
# 5e5849c5f76b1a73b0c4aa72
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5849cef76b1a73b0c4aa73
# 0
# 5e5849d0f76b1a73b0c4aa74
# 4
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1633)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1798)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2576)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4698)
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e5849dff76b1a73b0c4aa75
# 0
# 5e5849e2f76b1a73b0c4aa76
# 0
# 5e5849e3f76b1a73b0c4aa77
# 0
# 5e5849e5f76b1a73b0c4aa78
# 0
# 5e5849e8f76b1a73b0c4aa79
# 0
# 5e5849ebf76b1a73b0c4aa7a
# 0
# 5e5849eff76b1a73b0c4aa7b
# 0
# 5e5849f2f76b1a73b0c4aa7c
# 0
# 5e5849f6f76b1a73b0c4aa7d
# 0
# 5e5849f8f76b1a73b0c4aa7e
# 0
# 5e5849faf76b1a73b0c4aa7f
# 1
# Error:  Message: element click intercepted: Element is not clickable at point (471, 680)
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
# 5e584a02f76b1a73b0c4aa80
# 0
# 5e584a08f76b1a73b0c4aa81
# 0
# 5e584a0bf76b1a73b0c4aa82
# 0
# 5e584a0df76b1a73b0c4aa83
# 0
# 5e584a0ff76b1a73b0c4aa84
# 0
# 5e584a14f76b1a73b0c4aa85
# 0
# 5e584a16f76b1a73b0c4aa86
# 0
# 5e584a1af76b1a73b0c4aa87
# 0
# 5e584a1df76b1a73b0c4aa88
# 0
# 5e584a21f76b1a73b0c4aa89
# 0
# 5e584a23f76b1a73b0c4aa8a
# 13
# Error:  Message: element click intercepted: Element is not clickable at point (471, 807)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 940)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1181)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1267)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1492)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1994)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2095)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2969)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3148)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3670)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3987)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4088)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4787)
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584a46f76b1a73b0c4aa8b
# 0
# 5e584a48f76b1a73b0c4aa8c
# 0
# 5e584a4bf76b1a73b0c4aa8d
# 0
# 5e584a4df76b1a73b0c4aa8e
# 0
# 5e584a4ff76b1a73b0c4aa8f
# 0
# 5e584a51f76b1a73b0c4aa90
# 2
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e584a57f76b1a73b0c4aa91
# 0
# 5e584a59f76b1a73b0c4aa92
# 0
# 5e584a5bf76b1a73b0c4aa93
# 0
# 5e584a5df76b1a73b0c4aa94
# 0
# 5e584a5ff76b1a73b0c4aa95
# 0
# 5e584a64f76b1a73b0c4aa96
# 0
# 5e584a66f76b1a73b0c4aa97
# 0
# 5e584a71f76b1a73b0c4aa98
# 0
# 5e584a73f76b1a73b0c4aa99
# 0
# 5e584a75f76b1a73b0c4aa9a
# 0
# 5e584a77f76b1a73b0c4aa9b
# 0
# 5e584a7cf76b1a73b0c4aa9c
# 0
# 5e584a7ef76b1a73b0c4aa9d
# 0
# 5e584a80f76b1a73b0c4aa9e
# 0
# 5e584a83f76b1a73b0c4aa9f
# 0
# 5e584a85f76b1a73b0c4aaa0
# 2
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584a8cf76b1a73b0c4aaa1
# 0
# 5e584a8ef76b1a73b0c4aaa2
# 0
# 5e584a91f76b1a73b0c4aaa3
# 0
# 5e584a92f76b1a73b0c4aaa4
# 0
# 5e584a95f76b1a73b0c4aaa5
# 0
# 5e584a99f76b1a73b0c4aaa6
# 0
# 5e584aa1f76b1a73b0c4aaa7
# 0
# 5e584aa3f76b1a73b0c4aaa8
# 0
# 5e584aa8f76b1a73b0c4aaa9
# 0
# 5e584aaaf76b1a73b0c4aaaa
# 0
# 5e584aaef76b1a73b0c4aaab
# 0
# 5e584ab0f76b1a73b0c4aaac
# 0
# 5e584ab3f76b1a73b0c4aaad
# 0
# 5e584ab6f76b1a73b0c4aaae
# 0
# 5e584ab8f76b1a73b0c4aaaf
# 0
# 5e584abaf76b1a73b0c4aab0
# 0
# 5e584abdf76b1a73b0c4aab1
# 0
# 5e584abff76b1a73b0c4aab2
# 0
# 5e584ac2f76b1a73b0c4aab3
# 0
# 5e584ac5f76b1a73b0c4aab4
# 0
# 5e584ac9f76b1a73b0c4aab5
# 0
# 5e584ad0f76b1a73b0c4aab6
# 0
# 5e584ad2f76b1a73b0c4aab7
# 1
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e584adef76b1a73b0c4aab8
# 0
# 5e584ae0f76b1a73b0c4aab9
# 0
# 5e584ae2f76b1a73b0c4aaba
# 0
# 5e584ae5f76b1a73b0c4aabb
# 0
# 5e584ae6f76b1a73b0c4aabc
# 0
# 5e584ae9f76b1a73b0c4aabd
# 0
# 5e584aecf76b1a73b0c4aabe
# 0
# 5e584aeef76b1a73b0c4aabf
# 0
# 5e584af6f76b1a73b0c4aac0
# 0
# 5e584af8f76b1a73b0c4aac1
# 0
# 5e584afaf76b1a73b0c4aac2
# 0
# 5e584afff76b1a73b0c4aac3
# 0
# 5e584b01f76b1a73b0c4aac4
# 0
# 5e584b03f76b1a73b0c4aac5
# 0
# 5e584b06f76b1a73b0c4aac6
# 14
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1057)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1646)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2389)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2474)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2559)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2644)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2989)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3074)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3281)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3610)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3756)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3889)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4660)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 9684)
#   (Session info: chrome=80.0.3987.122)
#
# 5e584b2cf76b1a73b0c4aac7
# 0
# 5e584b2ff76b1a73b0c4aac8
# 0
# 5e584b33f76b1a73b0c4aac9
# 0
# 5e584b36f76b1a73b0c4aaca
# 1
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
# 5e584b40f76b1a73b0c4aacb
# 0
# 5e584b42f76b1a73b0c4aacc
# 0
# 5e584b44f76b1a73b0c4aacd
# 0
# 5e584b46f76b1a73b0c4aace
# 0
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./span[@dir='ltr']"}
#   (Session info: chrome=80.0.3987.122)
#
# 5e584b4bf76b1a73b0c4aacf
# 0
# 5e584b4df76b1a73b0c4aad0
# 0
# 5e584b52f76b1a73b0c4aad1
# 0
# 5e584b56f76b1a73b0c4aad2
# 0
# 5e584b58f76b1a73b0c4aad3
# 0
# 5e584b5af76b1a73b0c4aad4
# 0
# 5e584b5cf76b1a73b0c4aad5
# 0
# 5e584b5ef76b1a73b0c4aad6
# 14
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1057)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1646)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2389)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2474)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2559)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2644)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2989)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3074)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3281)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3610)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3756)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3889)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4660)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 9684)
#   (Session info: chrome=80.0.3987.122)
#
# 5e584b80f76b1a73b0c4aad7
# 0
# 5e584b82f76b1a73b0c4aad8
# 0
# 5e584b84f76b1a73b0c4aad9
# 0
# 5e584b86f76b1a73b0c4aada
# 0
# 5e584b8af76b1a73b0c4aadb
# 0
# 5e584b8ff76b1a73b0c4aadc
# 0
# 5e584b96f76b1a73b0c4aadd
# 0
# 5e584b98f76b1a73b0c4aade
# 0
# 5e584b9af76b1a73b0c4aadf
# 0
# 5e584b9cf76b1a73b0c4aae0
# 0
# 5e584ba0f76b1a73b0c4aae1
# 0
# 5e584ba2f76b1a73b0c4aae2
# 0
# 5e584ba6f76b1a73b0c4aae3
# 0
# 5e584ba8f76b1a73b0c4aae4
# 0
# 5e584baaf76b1a73b0c4aae5
# 0
# 5e584bacf76b1a73b0c4aae6
# 0
# 5e584baef76b1a73b0c4aae7
# 0
# 5e584bb0f76b1a73b0c4aae8
# 0
# 5e584bb2f76b1a73b0c4aae9
# 0
# 5e584bb3f76b1a73b0c4aaea
# 0
# 5e584bb5f76b1a73b0c4aaeb
# 0
# 5e584bbcf76b1a73b0c4aaec
# 0
# 5e584bbef76b1a73b0c4aaed
# 0
# 5e584bc3f76b1a73b0c4aaee
# 0
# 5e584bc5f76b1a73b0c4aaef
# 0
# 5e584bcaf76b1a73b0c4aaf0
# 0
# 5e584bccf76b1a73b0c4aaf1
# 0
# 5e584bcef76b1a73b0c4aaf2
# 0
# 5e584bd0f76b1a73b0c4aaf3
# 0
# 5e584bd2f76b1a73b0c4aaf4
# 0
# 5e584bd4f76b1a73b0c4aaf5
# 0
# 5e584bd6f76b1a73b0c4aaf6
# 0
# 5e584bdcf76b1a73b0c4aaf7
# 0
# 5e584bdef76b1a73b0c4aaf8
# 0
# 5e584be0f76b1a73b0c4aaf9
# 0
# 5e584be5f76b1a73b0c4aafa
# 0
# 5e584be7f76b1a73b0c4aafb
# 0
# 5e584be9f76b1a73b0c4aafc
# 0
# 5e584beaf76b1a73b0c4aafd
# 0
# 5e584becf76b1a73b0c4aafe
# 0
# 5e584bf1f76b1a73b0c4aaff
# 0
# 5e584bf8f76b1a73b0c4ab00
# 0
# 5e584bfaf76b1a73b0c4ab01
# 0
# 5e584bfcf76b1a73b0c4ab02
# 0
# 5e584bfff76b1a73b0c4ab03
# 0
# 5e584c02f76b1a73b0c4ab04
# 0
# 5e584c04f76b1a73b0c4ab05
# 0
# 5e584c06f76b1a73b0c4ab06
# 0
# 5e584c07f76b1a73b0c4ab07
# 0
# 5e584c0af76b1a73b0c4ab08
# 0
# 5e584c0bf76b1a73b0c4ab09
# 0
# 5e584c13f76b1a73b0c4ab0a
# 0
# 5e584c15f76b1a73b0c4ab0b
# 0
# 5e584c17f76b1a73b0c4ab0c
# 0
# 5e584c19f76b1a73b0c4ab0d
# 0
# 0
# 5e584cc7f76b1a73b0c4ab49
# 0
# 5e584ccdf76b1a73b0c4ab4a
# 0
# 5e584cd2f76b1a73b0c4ab4b
# 0
# 5e584cd4f76b1a73b0c4ab4c
# 0
# 5e584cd6f76b1a73b0c4ab4d
# 0
# 5e584cd8f76b1a73b0c4ab4e
# 0
# 5e584cdaf76b1a73b0c4ab4f
# 0
# 5e584cdcf76b1a73b0c4ab50
# 0
# 5e584cdef76b1a73b0c4ab51
# 0
# 5e584ce0f76b1a73b0c4ab52
# 0
# 5e584ce3f76b1a73b0c4ab53
# 0
# 5e584ce6f76b1a73b0c4ab54
# 27
# Error:  Message: element click intercepted: Element is not clickable at point (471, 966)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1051)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1136)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1221)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1306)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1661)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 1746)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2101)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 2456)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3081)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3436)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3521)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3876)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 3961)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4046)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4131)
#   (Session info: chrome=80.0.3987.122)
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4216)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4571)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4656)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 4741)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 5366)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 5721)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 5806)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 6161)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 6246)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 6493)
#   (Session info: chrome=80.0.3987.122)
#
# Error:  Message: element click intercepted: Element is not clickable at point (471, 6730)
#   (Session info: chrome=80.0.3987.122)
#
# 5e584d1cf76b1a73b0c4ab55
# 0
# 5e584d22f76b1a73b0c4ab56
# 0
# 5e584d25f76b1a73b0c4ab57
# 0
# 5e584d27f76b1a73b0c4ab58
# 0
# 5e584d2af76b1a73b0c4ab59
# 0
# 5e584d2cf76b1a73b0c4ab5a
# 0
# 5e584d31f76b1a73b0c4ab5b
# 0
# 5e584d33f76b1a73b0c4ab5c
# 0
# 5e584d35f76b1a73b0c4ab5d
# 0
# 5e584d37f76b1a73b0c4ab5e
# 0
# 5e584d39f76b1a73b0c4ab5f
# 0
# 5e584d3bf76b1a73b0c4ab60
# 0
# 5e584d3df76b1a73b0c4ab61
# 0
# 5e584d3ff76b1a73b0c4ab62
# 0
# 5e584d41f76b1a73b0c4ab63
# 0
# 5e584d44f76b1a73b0c4ab64
# 0
# 5e584d47f76b1a73b0c4ab65
# 0
# 5e584d49f76b1a73b0c4ab66
# 0
# 5e584d4bf76b1a73b0c4ab67
# 0
# 5e584d4df76b1a73b0c4ab68
# 0
# 5e584d4ff76b1a73b0c4ab69
# 0
# 5e584d51f76b1a73b0c4ab6a
# 0
# 5e584d53f76b1a73b0c4ab6b
# 0
# 5e584d55f76b1a73b0c4ab6c
# 0
# 5e584d57f76b1a73b0c4ab6d
# 0
# 5e584d59f76b1a73b0c4ab6e
# 0
# 5e584d5bf76b1a73b0c4ab6f
# 0
# 5e584d5df76b1a73b0c4ab70
# 0
# 5e584d5ff76b1a73b0c4ab71
# 0
# 5e584d61f76b1a73b0c4ab72
# 0
# 5e584d63f76b1a73b0c4ab73
# 0
# 5e584d65f76b1a73b0c4ab74
# 0
# 5e584d69f76b1a73b0c4ab75
# 0
# 5e584d6bf76b1a73b0c4ab76
# 0
# 5e584d6ef76b1a73b0c4ab77
# 0
# 5e584d70f76b1a73b0c4ab78
# 0
# 5e584d73f76b1a73b0c4ab79
# 0
# 5e584d75f76b1a73b0c4ab7a
# 0
# 5e584d77f76b1a73b0c4ab7b
# 0
# 5e584d79f76b1a73b0c4ab7c
# 4
# Error:  Message: element click intercepted: Element <div class="_4swz _1i3s _293g">...</div> is not clickable at point (471, 13). Other element would receive the click: <button value="1" class="_42ft _4jy0 _4w98 _4jy3 _517h _51sy" aria-label="Buscar" tabindex="-1" data-testid="facebar_search_button" type="submit">...</button>
#   (Session info: chrome=80.0.3987.122)
#
# 5e584d90f76b1a73b0c4ab7d
# 0
# 5e584d92f76b1a73b0c4ab7e
# 0
# 5e584d97f76b1a73b0c4ab7f
# 0
# 5e584d99f76b1a73b0c4ab80
# 0
# 5e584d9bf76b1a73b0c4ab81
# 0
# 5e584d9df76b1a73b0c4ab82
# 0
# 5e584d9ff76b1a73b0c4ab83
# 0
# 5e584da4f76b1a73b0c4ab84
# 0
# 5e584da6f76b1a73b0c4ab85
# 0
# 5e584da8f76b1a73b0c4ab86
# 0
# 5e584daaf76b1a73b0c4ab87
# 0
# 5e584dadf76b1a73b0c4ab88
# 0
# 5e584daff76b1a73b0c4ab89
# 0
# 5e584db1f76b1a73b0c4ab8a
# 0
# 5e584db3f76b1a73b0c4ab8b
# 0
# 5e584db9f76b1a73b0c4ab8c

# %%
data_post
# Out:
# {'post_id': '1657204474403464',
#  'post_link': 'https://www.facebook.com/groups/fierroscordobeses/permalink/1657204474403464/?sale_post_id=1657204474403464',
#  'date_post': datetime.datetime(2020, 2, 19, 18, 49, 36),
#  'user_link': 'https://www.facebook.com/leito.robledo.1?fref=gs&__tn__=%2Cdm-R-R&eid=ARBiwagzlkHXmuS2AtMb5ORWf5cpdvabKfZ_ibKN9xyiAFLjO7k5Qx3OTL2lfZJfdbbO-xwG7-bLUrDB&post_id=1657204474403464&dti=160048240785769&hc_location=group',
#  'user_name': 'Leo Robledo',
#  'msg_post': 'Vendo honda tornado modelo 2019 con 2700 kilómetros!!papeles al día listo para tranferir',
#  'comments_post': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTc1NjQzNzEwMzQxNDE',
#   'user_name_comment': 'Matias Villarreal',
#   'user_link_comment': 'https://www.facebook.com/matias.villarreal.5249?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTc1NjQzNzEwMzQxNDE%3D',
#   'post_comment': 'Tengo un palio 2009',
#   'date_comment': datetime.datetime(2020, 2, 20, 0, 17, 27),
#   'type': 'reply'},
#  'type': 'post',
#  '_id': ObjectId('5e542862f76b1a73b0c4a4a6')}

# %%
comments_post
# Out:
# {'0': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyMzE5NTEwNjczODM',
#   'user_name_comment': 'Luciano Ponce',
#   'user_link_comment': 'https://www.facebook.com/lucho.ponce1?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyMzE5NTEwNjczODM%3D',
#   'post_comment': 'Si te sirven 200 la busco mañana!',
#   'date_comment': datetime.datetime(2020, 2, 19, 19, 11, 15),
#   'type': 'reply'},
#  '1': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyMzY2NDc3MzM1ODA',
#   'user_name_comment': 'Chori Andrada',
#   'user_link_comment': 'https://www.facebook.com/marcelo.andrada.1293?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyMzY2NDc3MzM1ODA%3D',
#   'post_comment': 'Tw 2013 y cuanto ?lo hacemos ya ?',
#   'date_comment': datetime.datetime(2020, 2, 19, 19, 14, 8),
#   'type': 'reply'},
#  '2': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyNDIxNDEwNjYzNjQ',
#   'user_name_comment': 'Cacha Carrizo',
#   'user_link_comment': 'https://www.facebook.com/alfredo.carrizo.355?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyNDIxNDEwNjYzNjQ%3D',
#   'post_comment': 'Te sirve 220 de contado yaaa',
#   'date_comment': datetime.datetime(2020, 2, 19, 19, 17, 44),
#   'type': 'reply'},
#  '3': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyOTgxNjc3Mjc0Mjg',
#   'user_name_comment': 'Joni Scurti',
#   'user_link_comment': 'https://www.facebook.com/ScurtiJona?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTcyOTgxNjc3Mjc0Mjg%3D',
#   'post_comment': 'Martin Di Luca compramela pepona',
#   'date_comment': datetime.datetime(2020, 2, 19, 20, 8, 58),
#   'type': 'reply'},
#  '4': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTc1MTE4MzEwMzkzOTU',
#   'user_name_comment': 'Gonzalo Cabrera',
#   'user_link_comment': 'https://www.facebook.com/GonzaloCabreraFarias?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTc1MTE4MzEwMzkzOTU%3D',
#   'post_comment': 'Leo pasame tu numero asi te llamo mañana',
#   'date_comment': datetime.datetime(2020, 2, 19, 23, 31, 3),
#   'type': 'reply'},
#  '5': {'comment_id': 'Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTc1NjQzNzEwMzQxNDE',
#   'user_name_comment': 'Matias Villarreal',
#   'user_link_comment': 'https://www.facebook.com/matias.villarreal.5249?comment_id=Y29tbWVudDoxNjU3MjA0NDc0NDAzNDY0XzE2NTc1NjQzNzEwMzQxNDE%3D',
#   'post_comment': 'Tengo un palio 2009',
#   'date_comment': datetime.datetime(2020, 2, 20, 0, 17, 27),
#   'type': 'reply'}}

# %%
qw={}
for idx,i in enumerate(range(15)):
    qw[i]={i:i}
    print(idx)
qw
